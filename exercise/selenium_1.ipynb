# %%
from  selenium import webdriver

# %%
browser=webdriver.Chrome()
browser.get('https://www.baidu.com/s?wd=季薇璐')

# %%
dir(browser)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__enter__',
#  '__exit__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_file_detector',
#  '_is_remote',
#  '_mobile',
#  '_switch_to',
#  '_unwrap_value',
#  '_web_element_cls',
#  '_wrap_value',
#  'add_cookie',
#  'application_cache',
#  'back',
#  'capabilities',
#  'close',
#  'command_executor',
#  'create_options',
#  'create_web_element',
#  'current_url',
#  'current_window_handle',
#  'delete_all_cookies',
#  'delete_cookie',
#  'desired_capabilities',
#  'error_handler',
#  'execute',
#  'execute_async_script',
#  'execute_cdp_cmd',
#  'execute_script',
#  'file_detector',
#  'file_detector_context',
#  'find_element',
#  'find_element_by_class_name',
#  'find_element_by_css_selector',
# ...

# %%
browser.page_source
# Out:
# u'<!DOCTYPE html><!--STATUS OK--><html xmlns="http://www.w3.org/1999/xhtml"><head>\n\t\t\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\n\t\t<meta http-equiv="content-type" content="text/html;charset=utf-8" />\n\t\t<meta content="always" name="referrer" />\n        <meta name="theme-color" content="#2932e1" />\n        <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon" />\n        <link rel="icon" sizes="any" mask="" href="//www.baidu.com/img/baidu_85beaf5496f291521eb75ba38eacbd87.svg" />\n        <link rel="search" type="application/opensearchdescription+xml" href="/content-search.xml" title="\u767e\u5ea6\u641c\u7d22" />\n\t\t\n\t\t\n<title>\u5b63\u8587\u7490_\u767e\u5ea6\u641c\u7d22</title>\n\n\t\t\n\n\t\t\n<style data-for="result" type="text/css" id="css_newi_result">body{color:#333;background:#fff;padding:6px 0 0;margin:0;position:relative;min-width:900px}\nbody,th,td,.p1,.p2{font-family:arial}\np,form,ol,ul,li,dl,dt,dd,h3{margin:0;padding:0;
# ...

# %%
html = browser.page_source

# %%
from pyquery import PyQuery as pq

# %%
doc = pq(html)

# %%
doc('#2')
# Out:
# [<{http://www.w3.org/1999/xhtml}div#2.result.c-container.>]

# %%
doc('#2').find('a')
# Out:
# []

# %%
doc('#2')
# Out:
# [<{http://www.w3.org/1999/xhtml}div#2.result.c-container.>]

# %%
doc('#2').html()
# Out:
# u'<h3 xmlns="http://www.w3.org/1999/xhtml" class="t"><a data-click="{&#10;&#9;&#9;&#9;\'F\':\'778317EA\',&#10;&#9;&#9;&#9;\'F1\':\'9D73F1E4\',&#10;&#9;&#9;&#9;\'F2\':\'4CA6DE6B\',&#10;&#9;&#9;&#9;\'F3\':\'54E5243F\',&#10;&#9;&#9;&#9;\'T\':\'1543316581\',&#10;&#9;&#9;&#9;&#9;&#9;&#9;\'y\':\'FFFCFF3B\'&#10;&#9;&#9;&#9; &#10;&#9;&#9;&#9;&#9;&#9;&#9;&#9;&#9;&#9;}" href="http://www.baidu.com/link?url=JkMfA-UD0vg3TuJ-cEuN2DZo7dXDVAnOaNMnH_pqPonPJQLQg54hfOz9F3Ffzscrg5kF609th43PXtJDkqxzKXrVbqyKURQ3zeETjVymbY_" target="_blank"><em>\u5b63\u8587\u7490</em></a></h3><div xmlns="http://www.w3.org/1999/xhtml" class="c-abstract"><em>\u5b63\u8587\u7490</em>,<em>\u5b63\u8587\u7490</em>\u540c\u540d\u4eba,\u53eb<em>\u5b63\u8587\u7490</em>\u7684\u540c\u540d\u4eba,<em>\u5b63\u8587\u7490</em>\u540d\u5b57\u5206\u6790,<em>\u5b63\u8587\u7490</em>\u540d\u5b57\u914d\u5bf9\u6d4b\u8bd5,<em>\u5b63\u8587\u7490</em>\u59d3\u540d\u914d\u5bf9,<em>\u5b63\u8587\u7490</em>\u5173\u7cfb\u6d4b\u7b97,\u5bfb\u627e<em>\u5b63\u8
# ...
