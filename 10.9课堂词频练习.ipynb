# %%
from nltk.corpus import PlaintextCorpusReader

# %%
from nltk import word_tokenize

# %%
from nltk import Text

# %%
from nltk import FreqDist

# %%
corpus_root='/Users/jiweilu/Desktop/corpara'

# %%
files=PlaintextCorpusReader(corpus_root,'.*\.txt')

# %%
files.fileids()#找到文件
# Out:
# ['1.txt', '2.txt', '3.txt', '4.txt', '5.txt']

# %%
words=word_tokenize(files.raw(fileids=files.fileids()))

# %%
words
# Out:
# [u'The',
#  u'next',
#  u'financial',
#  u'crisis',
#  u'may',
#  u'be',
#  u'triggered',
#  u'by',
#  u'central',
#  u'banks',
#  u'.',
#  u'As',
#  u'with',
#  u'London',
#  u'buses',
#  u',',
#  u'don',
#  u'\u2019',
#  u't',
#  u'worry',
#  u'if',
#  u'you',
#  u'miss',
#  u'a',
#  u'financial',
#  u'crisis',
#  u';',
#  u'another',
#  u'will',
#  u'be',
#  u'along',
#  u'shortly',
#  u'.',
#  u'The',
#  u'latest',
#  u'study',
#  u'on',
#  u'long-term',
#  u'asset',
#  u'returns',
#  u'from',
#  u'Deutsche',
#  u'Bank',
#  u'shows',
#  u'that',
#  u'crises',
#  u'in',
#  u'developed',
#  u'markets',
#  u'have',
#  u'become',
#  u'much',
#  u'more',
#  u'common',
#  u'in',
#  u'recent',
#  u'decades',
#  u'.',
#  u'That',
#  u'does',
#  u'not',
#  u'bode',
#  u'well',
#  u'.',
#  u'Deutsche',
#  u'defines',
#  u'a',
#  u'crisis',
#  u'as',
#  u'a',
#  u'period',
#  u'when',
#  u'a',
#  u'country',
#  u'suffers',
#  u'one',
#  u'of',
#  u'the',
#  u'following',
#  u':',
#  u'a',
# ...

# %%
fdistl=FreqDist(cpsl)#函数FreqDist 函数FreqDist方法获取在文本中每个出现的标识符的频率分布。

# %%
fdistl.items()
# Out:
# [(u'limited', 2),
#  (u'managed', 2),
#  (u'global', 1),
#  (u'dollar', 1),
#  (u'month', 2),
#  (u'four', 1),
#  (u'per', 12),
#  (u'during', 1),
#  (u'chair', 1),
#  (u'crises', 2),
#  (u'young', 1),
#  (u'to', 45),
#  (u'under', 2),
#  (u'health', 1),
#  (u'reforms', 1),
#  (u'very', 2),
#  (u'Piyush', 1),
#  (u'bounceback', 1),
#  (u'railways', 1),
#  (u'mid-1970s', 2),
#  (u'every', 2),
#  (u'softened', 1),
#  (u'fall', 2),
#  (u'10-year', 1),
#  (u'bubbles', 2),
#  (u'governments', 2),
#  (u'Yearly', 1),
#  (u'washing', 1),
#  (u'did', 3),
#  (u'shock', 2),
#  (u'companies', 2),
#  (u'deals', 2),
#  (u'noted', 1),
#  (u'programme', 1),
#  (u'prevent', 1),
#  (u'post-meeting', 1),
#  (u'hardening', 1),
#  (u'10m', 1),
#  (u'trend', 2),
#  (u'harder', 2),
#  (u'cash', 1),
#  (u'rate', 7),
#  (u'Deficit', 1),
#  (u'subordinate', 2),
#  (u'estimated', 1),
#  (u'machines', 1),
#  (u'Janet', 1),
#  (u'consumers', 2),
#  (u'debate', 1),
#  (u'19th', 2),
#  (u'panded', 1),
# ...

# %%
wl=fdistl.items()

# %%
wl_sorted_desc=sorted(wl, key=lambda w:w[1], reverse=True)  #通过sorted方法，指定排序的键值key是原来字典中的value属性，其中用到了匿名函数lambda， 参数为t列表，返回第二个元素t[1]，也就是每个键值对中的value，  从小到大排序时 reverse=False，从大到小排序是True
wl_sorted_desc
# Out:
# [(u'the', 109),
#  (u'.', 72),
#  (u',', 71),
#  (u'a', 52),
#  (u'of', 50),
#  (u'to', 45),
#  (u'in', 41),
#  (u'and', 29),
#  (u'\u2019', 27),
#  (u's', 23),
#  (u'The', 20),
#  (u'on', 20),
#  (u'has', 19),
#  (u'for', 19),
#  (u'its', 18),
#  (u'that', 17),
#  (u'more', 14),
#  (u'year', 14),
#  (u'since', 14),
#  (u'have', 14),
#  (u'per', 12),
#  (u';', 12),
#  (u'cent', 12),
#  (u'by', 12),
#  (u'as', 11),
#  (u'crisis', 10),
#  (u'economy', 10),
#  (u'was', 10),
#  (u'financial', 9),
#  (u'said', 9),
#  (u'been', 9),
#  (u'is', 9),
#  (u'from', 8),
#  (u'would', 8),
#  (u'currency', 8),
#  (u'than', 8),
#  (u'it', 8),
#  (u'trade', 8),
#  (u'rate', 7),
#  (u'not', 7),
#  (u'system', 7),
#  (u'which', 7),
#  (u'country', 7),
#  (u'had', 7),
#  (u'US', 7),
#  (u'growth', 7),
#  (u'%', 7),
#  (u'markets', 6),
#  (u'Deutsche', 6),
#  (u'India', 6),
#  (u'Fed', 6),
#  (u'quarter', 6),
#  (u'\u201d', 6),
#  (u'also', 6),
#  (u'\u201c', 6),
#  (u'debt', 6),
#  (u'last', 6),
# ...

# %%
wl_sorted_asc=sorted(wl, key=lambda w:w[1])
wl_sorted_desc
# Out:
# [(u'the', 109),
#  (u'.', 72),
#  (u',', 71),
#  (u'a', 52),
#  (u'of', 50),
#  (u'to', 45),
#  (u'in', 41),
#  (u'and', 29),
#  (u'\u2019', 27),
#  (u's', 23),
#  (u'The', 20),
#  (u'on', 20),
#  (u'has', 19),
#  (u'for', 19),
#  (u'its', 18),
#  (u'that', 17),
#  (u'more', 14),
#  (u'year', 14),
#  (u'since', 14),
#  (u'have', 14),
#  (u'per', 12),
#  (u';', 12),
#  (u'cent', 12),
#  (u'by', 12),
#  (u'as', 11),
#  (u'crisis', 10),
#  (u'economy', 10),
#  (u'was', 10),
#  (u'financial', 9),
#  (u'said', 9),
#  (u'been', 9),
#  (u'is', 9),
#  (u'from', 8),
#  (u'would', 8),
#  (u'currency', 8),
#  (u'than', 8),
#  (u'it', 8),
#  (u'trade', 8),
#  (u'rate', 7),
#  (u'not', 7),
#  (u'system', 7),
#  (u'which', 7),
#  (u'country', 7),
#  (u'had', 7),
#  (u'US', 7),
#  (u'growth', 7),
#  (u'%', 7),
#  (u'markets', 6),
#  (u'Deutsche', 6),
#  (u'India', 6),
#  (u'Fed', 6),
#  (u'quarter', 6),
#  (u'\u201d', 6),
#  (u'also', 6),
#  (u'\u201c', 6),
#  (u'debt', 6),
#  (u'last', 6),
# ...

# %%
a = '你好'

# %%
a.decode('utf-8')
# Out:
# u'\u4f60\u597d'

# %%
print u'\u4f60\u597d'
# Out:
# 你好

# %%
a.decode('gbk')
# Out:
# u'\u6d63\u72b2\u30bd'

# %%
print u'\u6d63\u72b2\u30bd'
# Out:
# 浣犲ソ
